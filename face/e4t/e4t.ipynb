# %%
# !python inference.py \
  --pretrained_model_name_or_path "../../logs/face/e4t/000001/30" \
  --prompt "*s in the jungle" \
  --num_images_per_prompt 3 \
  --scheduler_type "ddim" \
  --image_path_or_url "../../pcs_dataset/face/000001/face.jpg" \
  --num_inference_steps 50 \
  --guidance_scale 7.5
# Out:
# device: cuda
# /home/huwentao/anaconda3/envs/e4t/lib/python3.9/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Resuming from ../../logs/face/e4t/000001/30/unet.pt
# Resuming from ../../logs/face/e4t/000001/30/encoder.pt
# Fetching 16 files: 100%|████████████████████| 16/16 [00:00<00:00, 164080.35it/s]
# loaded pipeline
# ...
# 100%|█████████████████████████████████████████████| 1/1 [00:21<00:00, 21.41s/it]
# DONE! See `grid.png` for the results!
